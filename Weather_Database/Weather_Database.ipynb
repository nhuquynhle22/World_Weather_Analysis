# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import gmaps
from datetime import datetime
from citipy import citipy

# %%
#3. Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#4. Get the nearest city using the citipy module.
coordinates = list(lat_lngs)
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
# 5. Perform an API call with the OpenWeatherMap.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_wdesc = city_weather["weather"][0]["description"]
        try:
            city_rain = city_weather["rain"]
            try:
                city_rain_value = city_rain["3h"]
            except KeyError:
                city_rain_value = city_rain["1h"]
        except KeyError:
            city_rain_value = 0
        try:
            city_snow = city_weather["snow"]
            try:
                city_snow_value = city_snow["3h"]
            except KeyError:
                city_snow_value = city_snow["1h"]
        except KeyError:
            city_snow_value = 0
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_wdesc,
                          "Rain (inches)": city_rain_value,
                          "Snow (inches)": city_snow_value})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

    # Indicate that Data Loading is complete.
    print("-----------------------------")
    print("Data Retrieval Complete      ")
    print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | rosetown
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 2 of Set 1 | samarai
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 3 of Set 1 | cape town
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 4 of Set 1 | kristiansund
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 5 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 6 of Set 1 | albany
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 7 of Set 1 | ushuaia
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 8 of Set 1 | yellowknife
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 9 of Set 1 | port alfred
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 10 of Set 1 | zhongshu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 11 of Set 1 | busselton
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 12 of Set 1 | tasiilaq
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 13 of Set 1 | hofn
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 14 of Set 1 | new norfolk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 15 of Set 1 | tuktoyaktuk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 16 of Set 1 | saint-philippe
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 17 of Set 1 | katherine
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 18 of Set 1 | nemuro
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 19 of Set 1 | bourail
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 20 of Set 1 | port lincoln
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 21 of Set 1 | plettenberg bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 22 of Set 1 | sena madureira
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 23 of Set 1 | mehamn
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 24 of Set 1 | sitka
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 25 of Set 1 | grand river south east
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 26 of Set 1 | griffith
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 27 of Set 1 | rikitea
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 28 of Set 1 | kloulklubed
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 29 of Set 1 | vaini
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 30 of Set 1 | kapaa
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 31 of Set 1 | atuona
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 32 of Set 1 | esperance
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 33 of Set 1 | lebu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 34 of Set 1 | porbandar
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 35 of Set 1 | chuy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 36 of Set 1 | mar del plata
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 37 of Set 1 | baghdad
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 38 of Set 1 | vanavara
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 39 of Set 1 | east london
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 40 of Set 1 | rumonge
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 41 of Set 1 | bengkulu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 42 of Set 1 | saint-francois
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 43 of Set 1 | sola
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 44 of Set 1 | barrow
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 45 of Set 1 | tuatapere
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 46 of Set 1 | maniitsoq
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 47 of Set 1 | hithadhoo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 48 of Set 1 | moose factory
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 49 of Set 1 | hermanus
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 50 of Set 1 | punta arenas
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 1 of Set 2 | hilo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 2 of Set 2 | waipawa
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 3 of Set 2 | tiksi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 4 of Set 2 | mabama
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 5 of Set 2 | tigil
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 6 of Set 2 | paracuru
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 7 of Set 2 | kamenskoye
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 8 of Set 2 | mahebourg
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 9 of Set 2 | shimanovsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 10 of Set 2 | touros
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 11 of Set 2 | innisfail
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 12 of Set 2 | carnarvon
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 13 of Set 2 | barentsburg
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 14 of Set 2 | katima mulilo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 15 of Set 2 | alta gracia
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 16 of Set 2 | hobart
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 17 of Set 2 | sentyabrskiy
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 18 of Set 2 | roma
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 19 of Set 2 | port elizabeth
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 20 of Set 2 | chernyshevskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 21 of Set 2 | nelson bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 22 of Set 2 | butaritari
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 23 of Set 2 | nanortalik
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 24 of Set 2 | norman wells
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 25 of Set 2 | baft
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 26 of Set 2 | fort saint james
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 27 of Set 2 | kodiak
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 28 of Set 2 | belushya guba
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 29 of Set 2 | bluff
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 30 of Set 2 | mergui
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 31 of Set 2 | college
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 32 of Set 2 | awbari
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 33 of Set 2 | saleaula
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 34 of Set 2 | acapulco
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 35 of Set 2 | walvis bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 36 of Set 2 | arraial do cabo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 37 of Set 2 | lat yao
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 38 of Set 2 | ambilobe
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 39 of Set 2 | surgut
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 40 of Set 2 | staryy cherek
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 41 of Set 2 | salalah
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 42 of Set 2 | bredasdorp
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 43 of Set 2 | mataura
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 44 of Set 2 | cabo san lucas
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 45 of Set 2 | qaanaaq
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 46 of Set 2 | grindavik
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 47 of Set 2 | cherskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 48 of Set 2 | pavlohrad
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 49 of Set 2 | dingle
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 50 of Set 2 | mount darwin
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 1 of Set 3 | hovd
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 2 of Set 3 | micomeseng
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 3 of Set 3 | taolanaro
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 4 of Set 3 | miri
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 5 of Set
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 27 of Set 14 | never
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 28 of Set 14 | toliary
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 29 of Set 14 | ust-kut
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 30 of Set 14 | batagay
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 31 of Set 14 | adelaide
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 32 of Set 14 | langen
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 33 of Set 14 | tornio
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 34 of Set 14 | lahaina
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 35 of Set 14 | olga
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 36 of Set 14 | mae hong son
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 37 of Set 14 | kalabo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 38 of Set 14 | anadyr
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 39 of Set 14 | lagoa
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 40 of Set 14 | lydenburg
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 41 of Set 14 | nizhnevartovsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 42 of Set 14 | barra
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 43 of Set 14 | sinnamary
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 44 of Set 14 | yerbogachen
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 45 of Set 14 | erechim
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 46 of Set 14 | dhidhdhoo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 47 of Set 14 | rivadavia
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 48 of Set 14 | kautokeino
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 49 of Set 14 | ewo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 50 of Set 14 | noumea
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 1 of Set 15 | huanuni
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 2 of Set 15 | nicoya
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 3 of Set 15 | hukuntsi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 4 of Set 15 | kyaikkami
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 5 of Set 15 | coihaique
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 6 of Set 15 | atherton
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 7 of Set 15 | nyazepetrovsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 8 of Set 15 | lolua
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 9 of Set 15 | nhulunbuy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 10 of Set 15 | velikiy ustyug
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 11 of Set 15 | jibuti
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 12 of Set 15 | alofi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 13 of Set 15 | orocue
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 14 of Set 15 | kununurra
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 15 of Set 15 | sivaki
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 16 of Set 15 | tabou
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 17 of Set 15 | ryde
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 18 of Set 15 | cap malheureux
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 19 of Set 15 | fairhope
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 20 of Set 15 | bantry
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 21 of Set 15 | tommot
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 22 of Set 15 | bocana de paiwas
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 23 of Set 15 | adana
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 24 of Set 15 | toora-khem
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 25 of Set 15 | awjilah
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 26 of Set 15 | tokonou
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 27 of Set 15 | biak
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 28 of Set 15 | madimba
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 29 of Set 15 | mocuba
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 30 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 31 of Set 15 | manaus
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 32 of Set 15 | at-bashi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 33 of Set 15 | roald
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 34 of Set 15 | pudozh
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 35 of Set 15 | jadu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 36 of Set 15 | alibag
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 37 of Set 15 | monster
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 38 of Set 15 | rantepao
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 39 of Set 15 | lakes entrance
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 40 of Set 15 | iisaku
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 41 of Set 15 | atbasar
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 42 of Set 15 | vicencia
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 43 of Set 15 | haines junction
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 44 of Set 15 | vanimo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 45 of Set 15 | barawe
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 46 of Set 15 | belmonte
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 47 of Set 15 | sechura
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 48 of Set 15 | epe
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 49 of Set 15 | assare
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 50 of Set 15 | linshu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 1 of Set 16 | belaya gora
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 2 of Set 16 | auki
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 3 of Set 16 | kurmanayevka
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 4 of Set 16 | arman
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 5 of Set 16 | dalvik
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 6 of Set 16 | tamiahua
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 7 of Set 16 | wainwright
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 8 of Set 16 | tacoronte
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 9 of Set 16 | marzuq
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 10 of Set 16 | mongomo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 11 of Set 16 | goundi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Rosetown      CA  51.5501 -108.0014     56.98        30           8
# 1       Samarai      PG -10.6167  150.6667     79.18        83          92
# 2     Cape Town      ZA -33.9258   18.4232     63.27        58           0
# 3  Kristiansund      NO  63.1115    7.7320     60.85        88          40
# 4        Albany      US  42.6001  -73.9662     66.67        70         100
# 5       Ushuaia      AR -54.8000  -68.3000     49.66        62          40
# 6   Yellowknife      CA  62.4560 -114.3525     42.42        99          90
# 7   Port Alfred      ZA -33.5906   26.8910     62.56        69           0
# 8      Zhongshu      CN  24.5167  103.7667     60.91        86         100
# 9     Busselton      AU -33.6500  115.3333     44.10        80          30
#
#    Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0        8.05           clear sky            0.0            0.0
# 1       16.33     overcast clouds            0.0            0.0
# 2       11.50           clear sky            0.0            0.0
# 3        2.30    scattered clouds            0.0            0.0
# 4        1.01     overcast clouds            0.0            0.0
# 5        9.22          light rain            0.4            0.0
# 6       10.36     overcast clouds            0.0            0.0
# 7       18.25           clear sky            0.0            0.0
# 8        6.58     overcast clouds            0.0            0.0
# 9        8.75    scattered clouds            0.0            0.0

# %%
# Create the output file (CSV).
output_data_file = r'C:..\Weather_Database\WeatherPy_Database.csv'
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
